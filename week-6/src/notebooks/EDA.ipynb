# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/final.csv")

df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BY2NkZj...
# 1  https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 2  https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 3  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 4  https://m.media-amazon.com/images/M/MV5BYWZjMj...
#
#                                      Series_Title Released_Year Certificate  \
# 0                                      Goodfellas          1990           A
# 1  Star Wars: Episode V - The Empire Strikes Back          1980          UA
# 2                 One Flew Over the Cuckoo's Nest          1975           A
# 3                                        Hamilton          2020       PG-13
# 4                                    Gisaengchung          2019           A
#
#    Runtime                       Genre  IMDB_Rating  \
# 0  146 min     Biography, Crime, Drama     3.120701
# 1  124 min  Action, Adventure, Fantasy     3.120701
# 2  133 min                       Drama     3.120701
# 3  160 min   Biography, Drama, History     2.714364
# 4  132 min     Comedy, Drama, Thriller     2.714364
#
#                                             Overview  Meta_score  \
# 0  The story of Henry Hill and his life in the mo...    1.076033
# 1  After the Rebels are brutally overpowered by t...    0.336743
# 2  A criminal pleads insanity and is admitted to ...    0.429154
# 3  The real life of one of America's foremost fou...    1.076033
# 4  Greed and class discrimination threaten the ne...    1.630501
#
#           Director               Star1            Star2             Star3  \
# 0  Martin Scorsese      Robert De Niro       Ray Liotta         Joe Pesci
# 1   Irvin Kershner         Mark Hamill    Harrison Ford     Carrie Fisher
# 2     Milos Forman      Jack Nicholson  Louise Fletcher  Michael Berryman
# 3      Thomas Kail  Lin-Manuel Miranda     Phillipa Soo   Leslie Odom Jr.
# 4     Bong Joon Ho        Kang-ho Song     Lee Sun-kyun     Cho Yeo-jeong
#
#                     Star4  No_of_Votes        Gross
# 0         Lorraine Bracco     2.993059   46,836,394
# 1      Billy Dee Williams     3.526718  290,475,067
# 2            Peter Brocco     2.597827  112,000,000
# 3  Renée Elise Goldsberry    -0.724539          NaN
# 4            Choi Woo-sik     1.191130   53,367,844

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    969 non-null    str
#  1   Series_Title   969 non-null    str
#  2   Released_Year  969 non-null    str
#  3   Certificate    868 non-null    str
#  4   Runtime        969 non-null    str
#  5   Genre          969 non-null    str
#  6   IMDB_Rating    969 non-null    float64
#  7   Overview       969 non-null    str
#  8   Meta_score     969 non-null    float64
#  9   Director       969 non-null    str
#  10  Star1          969 non-null    str
#  11  Star2          969 non-null    str
#  12  Star3          969 non-null    str
#  13  Star4          969 non-null    str
#  14  No_of_Votes    969 non-null    float64
#  15  Gross          800 non-null    str
# dtypes: float64(3), str(13)
# memory usage: 121.3 KB

# %%
plt.figure(figsize=(10,6))

sns.heatmap(df.isnull(), cbar=False)

plt.title("Missing Values Heatmap")

plt.show()

# %%
plt.figure(figsize=(12,8))

corr = df.select_dtypes(include="number").corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Matrix")

plt.show()

# %%
df.hist(figsize=(12,10))

plt.tight_layout()

plt.show()

# %%
sns.countplot(x="IMDB_Rating", data=df)

plt.title("Target Distribution")

plt.show()
